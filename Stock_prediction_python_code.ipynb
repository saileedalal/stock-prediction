# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, SimpleRNN
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web

# %% [markdown]
# # **Stock Price Prediction**
#
# Given last 50 days of tesla price and S&P500, plot next five days of predicted tesla closing stock price, compare with actual. Show your results using comparative graphs as done for the flights data in example shared earlier.

# %%
Tesla = web.DataReader('TSLA',data_source = 'yahoo', start = '2016-01-01', end = '2019-12-31') #Extract data from yahoo finance website for Tesla and S&P 500
SP500 = web.DataReader('^GSPC',data_source = 'yahoo', start = '2016-01-01', end = '2019-12-31')

#Check both lengths are same. If you pull data from different stock echanges, the length might be different depending on holidays
print(len(Tesla['Open']))
print(len(SP500['Open'])) 


#You may get any other  ticker by searching here https://finance.yahoo.com/quote/
# Out:
# 1006
# 1006

# %%
SP500
# Out:
#                    High          Low  ...      Volume    Adj Close
# Date                                  ...
# 2016-01-04  2038.199951  1989.680054  ...  4304880000  2012.660034
# 2016-01-05  2021.939941  2004.170044  ...  3706620000  2016.709961
# 2016-01-06  2011.709961  1979.050049  ...  4336660000  1990.260010
# 2016-01-07  1985.319946  1938.829956  ...  5076590000  1943.089966
# 2016-01-08  1960.400024  1918.459961  ...  4664940000  1922.030029
# ...                 ...          ...  ...         ...          ...
# 2019-12-24  3226.429932  3220.510010  ...  1296540000  3223.379883
# 2019-12-26  3240.080078  3227.199951  ...  2160680000  3239.909912
# 2019-12-27  3247.929932  3234.370117  ...  2428670000  3240.020020
# 2019-12-30  3240.919922  3216.570068  ...  3013290000  3221.290039
# 2019-12-31  3231.719971  3212.030029  ...  2893810000  3230.780029
#
# [1006 rows x 6 columns]

# %%
Tesla
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2016-01-04  46.276001  43.799999  46.144001  44.681999  34135500  44.681999
# 2016-01-05  45.377998  44.000000  45.271999  44.686001  15934000  44.686001
# 2016-01-06  44.009998  43.195999  44.000000  43.807999  18895500  43.807999
# 2016-01-07  43.688000  42.734001  42.838001  43.130001  17771500  43.130001
# 2016-01-08  44.088001  42.153999  43.571999  42.200001  18140500  42.200001
# ...               ...        ...        ...        ...       ...        ...
# 2019-12-24  85.094002  82.538002  83.671997  85.050003  40273500  85.050003
# 2019-12-26  86.695999  85.269997  85.582001  86.188004  53169500  86.188004
# 2019-12-27  87.061996  85.222000  87.000000  86.075996  49728500  86.075996
# 2019-12-30  85.800003  81.851997  85.758003  82.940002  62932000  82.940002
# 2019-12-31  84.258003  80.416000  81.000000  83.666000  51428500  83.666000
#
# [1006 rows x 6 columns]

# %%
L = len(Tesla['Open'])
All_Data = np.concatenate((np.array(Tesla['Open']).reshape(L,1), np.array(Tesla['Close']).reshape(L,1), 
                           np.array(Tesla['High']).reshape(L,1), np.array(Tesla['Low']).reshape(L,1), np.array(Tesla['Volume']).reshape(L,1),
                           np.array(SP500['Open']).reshape(L,1), np.array(SP500['Close']).reshape(L,1),
                          np.array(SP500['High']).reshape(L,1), np.array(SP500['Low']).reshape(L,1), np.array(SP500['Volume']).reshape(L,1),), axis = 1)
plt.plot(np.array(Tesla['Close'])*10, 'r')  #Displayed at 10 times the scale for better visualization
plt.plot(np.array(SP500['Close']), 'b')

# %%
All_Data[1,5]
# Out:
# 2013.780029296875

# %%
All_Data
# Out:
# array([[4.61440010e+01, 4.46819992e+01, 4.62760010e+01, ...,
#         2.03819995e+03, 1.98968005e+03, 4.30488000e+09],
#        [4.52719994e+01, 4.46860008e+01, 4.53779984e+01, ...,
#         2.02193994e+03, 2.00417004e+03, 3.70662000e+09],
#        [4.40000000e+01, 4.38079987e+01, 4.40099983e+01, ...,
#         2.01170996e+03, 1.97905005e+03, 4.33666000e+09],
#        ...,
#        [8.70000000e+01, 8.60759964e+01, 8.70619965e+01, ...,
#         3.24792993e+03, 3.23437012e+03, 2.42867000e+09],
#        [8.57580032e+01, 8.29400024e+01, 8.58000031e+01, ...,
#         3.24091992e+03, 3.21657007e+03, 3.01329000e+09],
#        [8.10000000e+01, 8.36660004e+01, 8.42580032e+01, ...,
#         3.23171997e+03, 3.21203003e+03, 2.89381000e+09]])

# %%
All_Data.shape
# Out:
# (1006, 10)

# %% [markdown]
# Use sequences of 8 input arrays taken from All_Data. Each input will be of of length 50  (Last 50 days) and will be used to predict next five days. Try RNN, LSTM or GRU

# %%
# Creating the groups of 50 size inputs and 5 size output
# Prediction of opening price of each stock
# Normalisaton
Tesla_prior = []
Tesla_target = []
SP500_prior = []
SP500_target =[] 

# Individual Inputs for each stock 
Tesla_input = All_Data[:,0:5]
Tesla_input1 = All_Data[:,0] # This is used to obtain the target set for tesla stock price that is the opening price of tesla stock and similarly done for SP500 stocks
# In Tesla_input1 if index is changed then our target variable will be different and hence we can predict other parameters too.

SP500_input = All_Data[:,5:10]
SP500_input1 = All_Data[:,5]
for i in range(0,1006-55):
  T1 = np.array(Tesla_input[i:i+50])
  S1 = np.array(SP500_input[i:i+50])

  Max_Tesla = T1.max(0)
  Min_Tesla = T1.min(0)
  Max_Sp500 = S1.max(0)
  Min_Sp500 = S1.min(0)

  Tesla_prior.append((Tesla_input[i:i+50] - Min_Tesla)/Max_Tesla); # In all_data first 5 columns are of Tesla while the remaing belongs to SP500
  Tesla_target.append((Tesla_input1[i+50:i+55] - Min_Tesla[0])/Max_Tesla[0]); # The opening price for tesla is at 1st column that is 0th index
                                                                              # The opening price for SP500 is at 6th column that is 5th index
  SP500_prior.append((SP500_input[i:i+50] - Min_Sp500)/Max_Sp500);
  SP500_target.append((SP500_input1[i+50:i+55] - Min_Sp500[0])/Max_Sp500[0]);

Tesla_prior = np.array(Tesla_prior)
Tesla_target = np.array(Tesla_target)
SP500_prior = np.array(SP500_prior)
SP500_target = np.array(SP500_target)

# %%
Tesla_prior.shape
# Out:
# (951, 50, 5)

# %%
Tesla_target.shape
# Out:
# (951, 5)

# %%
SP500_prior.shape
# Out:
# (951, 50, 5)

# %%
SP500_target.shape
# Out:
# (951, 5)

# %%
xt_train, xt_test, yt_train, yt_test = train_test_split(Tesla_prior, Tesla_target, test_size = 0.2, random_state = 4);
xsp_train, xsp_test, ysp_train, ysp_test = train_test_split(SP500_prior, SP500_target, test_size = 0.2, random_state = 4);

# %%
xt_train.shape
# Out:
# (760, 50, 5)

# %%
yt_train.shape
# Out:
# (760, 5)

# %%
yt_test.shape
# Out:
# (191, 5)

# %%
# Model for Tesla Stocks
model = Sequential()
model.add(LSTM((128), batch_input_shape = (None,50 ,5), return_sequences = True))
model.add(LSTM((100), activation = 'relu', return_sequences = True))
model.add(LSTM((10), activation = 'relu', return_sequences = True))
model.add(LSTM((5), activation = 'relu', return_sequences = False))
model.compile(loss = 'mse',  optimizer = 'adam', metrics = ['mse'])
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_70 (LSTM)               (None, 50, 128)           68608
# _________________________________________________________________
# lstm_71 (LSTM)               (None, 50, 100)           91600
# _________________________________________________________________
# lstm_72 (LSTM)               (None, 50, 10)            4440
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 5)                 320
# =================================================================
# Total params: 164,968
# Trainable params: 164,968
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model1 for SP500 Stocks
model1 = Sequential()
model1.add(LSTM((128), batch_input_shape = (None,50 ,5), return_sequences = True))
model1.add(LSTM((100), activation = 'relu', return_sequences = True))
model1.add(LSTM((10), activation = 'relu', return_sequences = True))
model1.add(LSTM((5), activation = 'relu', return_sequences = False))
model1.compile(loss = 'mse',  optimizer = 'adam', metrics = ['mse'])
model1.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_74 (LSTM)               (None, 50, 128)           68608
# _________________________________________________________________
# lstm_75 (LSTM)               (None, 50, 100)           91600
# _________________________________________________________________
# lstm_76 (LSTM)               (None, 50, 10)            4440
# _________________________________________________________________
# lstm_77 (LSTM)               (None, 5)                 320
# =================================================================
# Total params: 164,968
# Trainable params: 164,968
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(xt_train, yt_train, epochs = 100, validation_data = (xt_test, yt_test)) # training for Tesla stocks

# %%
plt.plot(history.history['loss'])

# %%
# Plotting the predicted opening price and comparing with the original opening price in 5 days for Tesla
data_Start_Point = 15;
test_Data = Tesla_input[data_Start_Point:data_Start_Point+50];
Opening_Price = Tesla_input1[data_Start_Point:data_Start_Point+50]
A = np.array(test_Data)
Mi = A.min(0);
Mx = A.max(0);
actual_Target = Tesla_input1[data_Start_Point+50:data_Start_Point+55];
results = model.predict(((test_Data.reshape(50,5)-Mi)/Mx).reshape(1,50,5))
results = results*Mx[0] +Mi[0];
plt.title('Opening Price for Tesla stocks vs days')
plt.plot(range(0,50),Opening_Price, 'r')
plt.plot(range(50,55),results.reshape(5), 'g')
plt.plot(range(50,55),actual_Target, 'b')

# %%
# training for SP500 stocks
history1 = model1.fit(xsp_train, ysp_train, epochs = 100, validation_data = (xsp_test, ysp_test))
# Out:
# Epoch 1/100
# 24/24 [==============================] - 10s 185ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 2/100
# 24/24 [==============================] - 3s 144ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 3/100
# 24/24 [==============================] - 3s 146ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 4/100
# 24/24 [==============================] - 4s 147ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 5/100
# 24/24 [==============================] - 4s 147ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 6/100
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 7/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 8/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 9/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 10/100
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 11/100
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 12/100
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 13/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 14/100
# 24/24 [==============================] - 3s 142ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 15/100
# 24/24 [==============================] - 3s 138ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 16/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 17/100
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 18/100
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 19/100
# 24/24 [==============================] - 3s 140ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 6.0733e-04 - val_mse: 6.0733e-04
# Epoch 20/100
# 24/24 [==============================] - 3s 140ms/step - loss: 4.7833e-04 - mse: 4.7833e-04 - val_loss: 3.9276e-04 - val_mse: 3.9276e-04
# Epoch 21/100
# 24/24 [==============================] - 3s 143ms/step - loss: 3.1262e-04 - mse: 3.1262e-04 - val_loss: 3.4431e-04 - val_mse: 3.4431e-04
# Epoch 22/100
# 24/24 [==============================] - 3s 142ms/step - loss: 2.6936e-04 - mse: 2.6936e-04 - val_loss: 3.4494e-04 - val_mse: 3.4494e-04
# Epoch 23/100
# 24/24 [==============================] - 3s 143ms/step - loss: 2.8606e-04 - mse: 2.8606e-04 - val_loss: 3.2035e-04 - val_mse: 3.2035e-04
# Epoch 24/100
# 24/24 [==============================] - 3s 141ms/step - loss: 2.5264e-04 - mse: 2.5264e-04 - val_loss: 2.9047e-04 - val_mse: 2.9047e-04
# Epoch 25/100
# 24/24 [==============================] - 3s 143ms/step - loss: 2.3367e-04 - mse: 2.3367e-04 - val_loss: 2.7869e-04 - val_mse: 2.7869e-04
# Epoch 26/100
# 24/24 [==============================] - 3s 142ms/step - loss: 2.4954e-04 - mse: 2.4954e-04 - val_loss: 2.9284e-04 - val_mse: 2.9284e-04
# Epoch 27/100
# 24/24 [==============================] - 3s 140ms/step - loss: 2.5293e-04 - mse: 2.5293e-04 - val_loss: 2.7370e-04 - val_mse: 2.7370e-04
# Epoch 28/100
# 24/24 [==============================] - 3s 141ms/step - loss: 2.1747e-04 - mse: 2.1747e-04 - val_loss: 2.7755e-04 - val_mse: 2.7755e-04
# Epoch 29/100
# 24/24 [==============================] - 3s 140ms/step - loss: 2.1544e-04 - mse: 2.1544e-04 - val_loss: 2.4585e-04 - val_mse: 2.4585e-04
# Epoch 30/100
# 24/24 [==============================] - 3s 141ms/step - loss: 2.2360e-04 - mse: 2.2360e-04 - val_loss: 2.4721e-04 - val_mse: 2.4721e-04
# Epoch 31/100
# 24/24 [==============================] - 3s 142ms/step - loss: 2.0377e-04 - mse: 2.0377e-04 - val_loss: 2.4348e-04 - val_mse: 2.4348e-04
# Epoch 32/100
# 24/24 [==============================] - 3s 141ms/step - loss: 2.1099e-04 - mse: 2.1099e-04 - val_loss: 2.8367e-04 - val_mse: 2.8367e-04
# Epoch 33/100
# 24/24 [==============================] - 3s 142ms/step - loss: 2.0752e-04 - mse: 2.0752e-04 - val_loss: 2.3240e-04 - val_mse: 2.3240e-04
# Epoch 34/100
# 24/24 [==============================] - 3s 140ms/step - loss: 1.8990e-04 - mse: 1.8990e-04 - val_loss: 2.2406e-04 - val_mse: 2.2406e-04
# Epoch 35/100
# 24/24 [==============================] - 3s 139ms/step - loss: 2.0444e-04 - mse: 2.0444e-04 - val_loss: 2.2770e-04 - val_mse: 2.2770e-04
# Epoch 36/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.5554e-04 - mse: 1.5554e-04 - val_loss: 2.4640e-04 - val_mse: 2.4640e-04
# Epoch 37/100
# 24/24 [==============================] - 3s 141ms/step - loss: 2.0108e-04 - mse: 2.0108e-04 - val_loss: 2.0972e-04 - val_mse: 2.0972e-04
# Epoch 38/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.6523e-04 - mse: 1.6523e-04 - val_loss: 2.0691e-04 - val_mse: 2.0691e-04
# Epoch 39/100
# 24/24 [==============================] - 3s 143ms/step - loss: 1.6111e-04 - mse: 1.6111e-04 - val_loss: 2.0236e-04 - val_mse: 2.0236e-04
# Epoch 40/100
# 24/24 [==============================] - 3s 139ms/step - loss: 1.5772e-04 - mse: 1.5772e-04 - val_loss: 2.2138e-04 - val_mse: 2.2138e-04
# Epoch 41/100
# 24/24 [==============================] - 3s 140ms/step - loss: 1.6434e-04 - mse: 1.6434e-04 - val_loss: 2.0818e-04 - val_mse: 2.0818e-04
# Epoch 42/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.5420e-04 - mse: 1.5420e-04 - val_loss: 2.2083e-04 - val_mse: 2.2083e-04
# Epoch 43/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.5833e-04 - mse: 1.5833e-04 - val_loss: 2.0097e-04 - val_mse: 2.0097e-04
# Epoch 44/100
# 24/24 [==============================] - 3s 140ms/step - loss: 1.5200e-04 - mse: 1.5200e-04 - val_loss: 2.0331e-04 - val_mse: 2.0331e-04
# Epoch 45/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.4394e-04 - mse: 1.4394e-04 - val_loss: 2.0632e-04 - val_mse: 2.0632e-04
# Epoch 46/100
# 24/24 [==============================] - 3s 140ms/step - loss: 1.4149e-04 - mse: 1.4149e-04 - val_loss: 1.9958e-04 - val_mse: 1.9958e-04
# Epoch 47/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.4093e-04 - mse: 1.4093e-04 - val_loss: 1.9215e-04 - val_mse: 1.9215e-04
# Epoch 48/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.4743e-04 - mse: 1.4743e-04 - val_loss: 1.9605e-04 - val_mse: 1.9605e-04
# Epoch 49/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.3896e-04 - mse: 1.3896e-04 - val_loss: 1.5734e-04 - val_mse: 1.5734e-04
# Epoch 50/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.3164e-04 - mse: 1.3164e-04 - val_loss: 1.5596e-04 - val_mse: 1.5596e-04
# Epoch 51/100
# 24/24 [==============================] - 3s 139ms/step - loss: 1.3200e-04 - mse: 1.3200e-04 - val_loss: 1.6868e-04 - val_mse: 1.6868e-04
# Epoch 52/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1538e-04 - mse: 1.1538e-04 - val_loss: 1.6501e-04 - val_mse: 1.6501e-04
# Epoch 53/100
# 24/24 [==============================] - 3s 139ms/step - loss: 1.1936e-04 - mse: 1.1936e-04 - val_loss: 1.6171e-04 - val_mse: 1.6171e-04
# Epoch 54/100
# 24/24 [==============================] - 3s 140ms/step - loss: 1.2495e-04 - mse: 1.2495e-04 - val_loss: 1.5294e-04 - val_mse: 1.5294e-04
# Epoch 55/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1106e-04 - mse: 1.1106e-04 - val_loss: 1.5697e-04 - val_mse: 1.5697e-04
# Epoch 56/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.0202e-04 - mse: 1.0202e-04 - val_loss: 1.4580e-04 - val_mse: 1.4580e-04
# Epoch 57/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.0995e-04 - mse: 1.0995e-04 - val_loss: 1.5971e-04 - val_mse: 1.5971e-04
# Epoch 58/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1549e-04 - mse: 1.1549e-04 - val_loss: 1.4449e-04 - val_mse: 1.4449e-04
# Epoch 59/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1646e-04 - mse: 1.1646e-04 - val_loss: 1.4071e-04 - val_mse: 1.4071e-04
# Epoch 60/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1120e-04 - mse: 1.1120e-04 - val_loss: 1.5286e-04 - val_mse: 1.5286e-04
# Epoch 61/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.0892e-04 - mse: 1.0892e-04 - val_loss: 1.3598e-04 - val_mse: 1.3598e-04
# Epoch 62/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.1975e-04 - mse: 1.1975e-04 - val_loss: 1.6590e-04 - val_mse: 1.6590e-04
# Epoch 63/100
# 24/24 [==============================] - 3s 143ms/step - loss: 1.0561e-04 - mse: 1.0561e-04 - val_loss: 1.3408e-04 - val_mse: 1.3408e-04
# Epoch 64/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.1186e-04 - mse: 1.1186e-04 - val_loss: 1.3495e-04 - val_mse: 1.3495e-04
# Epoch 65/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.0149e-04 - mse: 1.0149e-04 - val_loss: 1.2633e-04 - val_mse: 1.2633e-04
# Epoch 66/100
# 24/24 [==============================] - 3s 141ms/step - loss: 9.5602e-05 - mse: 9.5602e-05 - val_loss: 1.4931e-04 - val_mse: 1.4931e-04
# Epoch 67/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.0618e-04 - mse: 1.0618e-04 - val_loss: 1.3916e-04 - val_mse: 1.3916e-04
# Epoch 68/100
# 24/24 [==============================] - 3s 142ms/step - loss: 1.0101e-04 - mse: 1.0101e-04 - val_loss: 1.2483e-04 - val_mse: 1.2483e-04
# Epoch 69/100
# 24/24 [==============================] - 3s 141ms/step - loss: 1.0022e-04 - mse: 1.0022e-04 - val_loss: 1.2541e-04 - val_mse: 1.2541e-04
# Epoch 70/100
# 24/24 [==============================] - 3s 140ms/step - loss: 9.3245e-05 - mse: 9.3245e-05 - val_loss: 1.1924e-04 - val_mse: 1.1924e-04
# Epoch 71/100
# 24/24 [==============================] - 3s 142ms/step - loss: 8.6670e-05 - mse: 8.6670e-05 - val_loss: 1.1700e-04 - val_mse: 1.1700e-04
# Epoch 72/100
# 24/24 [==============================] - 3s 142ms/step - loss: 8.6783e-05 - mse: 8.6783e-05 - val_loss: 1.2366e-04 - val_mse: 1.2366e-04
# Epoch 73/100
# 24/24 [==============================] - 3s 143ms/step - loss: 9.7482e-05 - mse: 9.7482e-05 - val_loss: 1.3933e-04 - val_mse: 1.3933e-04
# Epoch 74/100
# 24/24 [==============================] - 4s 147ms/step - loss: 9.0484e-05 - mse: 9.0484e-05 - val_loss: 1.1236e-04 - val_mse: 1.1236e-04
# Epoch 75/100
# 24/24 [==============================] - 3s 143ms/step - loss: 9.0066e-05 - mse: 9.0066e-05 - val_loss: 1.3163e-04 - val_mse: 1.3163e-04
# Epoch 76/100
# 24/24 [==============================] - 3s 142ms/step - loss: 9.0830e-05 - mse: 9.0830e-05 - val_loss: 1.1338e-04 - val_mse: 1.1338e-04
# Epoch 77/100
# 24/24 [==============================] - 3s 144ms/step - loss: 8.1980e-05 - mse: 8.1980e-05 - val_loss: 1.0492e-04 - val_mse: 1.0492e-04
# Epoch 78/100
# 24/24 [==============================] - 3s 141ms/step - loss: 9.5235e-05 - mse: 9.5235e-05 - val_loss: 1.1309e-04 - val_mse: 1.1309e-04
# Epoch 79/100
# 24/24 [==============================] - 3s 142ms/step - loss: 7.6333e-05 - mse: 7.6333e-05 - val_loss: 9.9002e-05 - val_mse: 9.9002e-05
# Epoch 80/100
# 24/24 [==============================] - 3s 143ms/step - loss: 8.3408e-05 - mse: 8.3408e-05 - val_loss: 1.2795e-04 - val_mse: 1.2795e-04
# Epoch 81/100
# 24/24 [==============================] - 3s 140ms/step - loss: 8.6577e-05 - mse: 8.6577e-05 - val_loss: 1.0109e-04 - val_mse: 1.0109e-04
# Epoch 82/100
# 24/24 [==============================] - 3s 142ms/step - loss: 7.6928e-05 - mse: 7.6928e-05 - val_loss: 1.0815e-04 - val_mse: 1.0815e-04
# Epoch 83/100
# 24/24 [==============================] - 3s 145ms/step - loss: 6.9367e-05 - mse: 6.9367e-05 - val_loss: 1.0085e-04 - val_mse: 1.0085e-04
# Epoch 84/100
# 24/24 [==============================] - 4s 150ms/step - loss: 6.9103e-05 - mse: 6.9103e-05 - val_loss: 1.0206e-04 - val_mse: 1.0206e-04
# Epoch 85/100
# 24/24 [==============================] - 4s 147ms/step - loss: 6.8440e-05 - mse: 6.8440e-05 - val_loss: 9.9961e-05 - val_mse: 9.9961e-05
# Epoch 86/100
# 24/24 [==============================] - 4s 147ms/step - loss: 7.6101e-05 - mse: 7.6101e-05 - val_loss: 9.8720e-05 - val_mse: 9.8720e-05
# Epoch 87/100
# 24/24 [==============================] - 3s 144ms/step - loss: 6.0724e-05 - mse: 6.0724e-05 - val_loss: 9.7346e-05 - val_mse: 9.7346e-05
# Epoch 88/100
# 24/24 [==============================] - 3s 141ms/step - loss: 6.7618e-05 - mse: 6.7618e-05 - val_loss: 1.0740e-04 - val_mse: 1.0740e-04
# Epoch 89/100
# 24/24 [==============================] - 3s 143ms/step - loss: 7.0220e-05 - mse: 7.0220e-05 - val_loss: 9.7377e-05 - val_mse: 9.7377e-05
# Epoch 90/100
# 24/24 [==============================] - 3s 144ms/step - loss: 8.0177e-05 - mse: 8.0177e-05 - val_loss: 8.3539e-05 - val_mse: 8.3539e-05
# Epoch 91/100
# 24/24 [==============================] - 3s 144ms/step - loss: 7.0380e-05 - mse: 7.0380e-05 - val_loss: 8.6846e-05 - val_mse: 8.6846e-05
# Epoch 92/100
# 24/24 [==============================] - 3s 145ms/step - loss: 6.5085e-05 - mse: 6.5085e-05 - val_loss: 8.4119e-05 - val_mse: 8.4119e-05
# Epoch 93/100
# 24/24 [==============================] - 4s 147ms/step - loss: 5.9800e-05 - mse: 5.9800e-05 - val_loss: 1.0476e-04 - val_mse: 1.0476e-04
# Epoch 94/100
# 24/24 [==============================] - 3s 145ms/step - loss: 6.9489e-05 - mse: 6.9489e-05 - val_loss: 8.8824e-05 - val_mse: 8.8824e-05
# Epoch 95/100
# 24/24 [==============================] - 3s 142ms/step - loss: 6.0870e-05 - mse: 6.0870e-05 - val_loss: 8.4154e-05 - val_mse: 8.4154e-05
# Epoch 96/100
# 24/24 [==============================] - 3s 142ms/step - loss: 6.5732e-05 - mse: 6.5732e-05 - val_loss: 9.0367e-05 - val_mse: 9.0367e-05
# Epoch 97/100
# 24/24 [==============================] - 3s 143ms/step - loss: 6.2334e-05 - mse: 6.2334e-05 - val_loss: 1.0266e-04 - val_mse: 1.0266e-04
# Epoch 98/100
# 24/24 [==============================] - 3s 143ms/step - loss: 8.0873e-05 - mse: 8.0873e-05 - val_loss: 1.0062e-04 - val_mse: 1.0062e-04
# Epoch 99/100
# 24/24 [==============================] - 3s 143ms/step - loss: 6.1412e-05 - mse: 6.1412e-05 - val_loss: 8.4174e-05 - val_mse: 8.4174e-05
# Epoch 100/100
# 24/24 [==============================] - 3s 142ms/step - loss: 5.3963e-05 - mse: 5.3963e-05 - val_loss: 8.6952e-05 - val_mse: 8.6952e-05

# %%
plt.plot(history.history['loss'])

# %%
# Plotting the predicted opening price and comparing with the original opening price in 5 days for Tesla
data_Start_Point = 15;
test_Data = SP500_input[data_Start_Point:data_Start_Point+50];
Opening_Price = SP500_input1[data_Start_Point:data_Start_Point+50];
A = np.array(test_Data)
Mi = A.min(0);
Mx = A.max(0);
actual_Target = SP500_input1[data_Start_Point+50:data_Start_Point+55];
results = model1.predict(((test_Data.reshape(50,5)-Mi)/Mx).reshape(1,50,5))
results = results*Mx[0] +Mi[0];
plt.title('Opening Price for SP500 stocks vs days ')
plt.plot(range(0,50),Opening_Price, 'r')
plt.plot(range(50,55),results.reshape(5), 'g')
plt.plot(range(50,55),actual_Target, 'b')
